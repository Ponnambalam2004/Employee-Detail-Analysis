# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r'C:\Users\Ponnambalam\OneDrive\Desktop\Employees__data.xlsx')

# %%
df
# Out:
#      Unnamed: 0  employee_id    Employee_name                     Age  \
# 0             0            1  Joachim Coulman   Network Administrator
# 1             1            2    Fidela Fetter     IT Business Analyst
# 2             2            3     Myles Laffan         Cloud Architect
# 3             3            4   Myrtie Rraundl   Network Administrator
# 4             4            5       Janie Burd   Cybersecurity Analyst
# ..          ...          ...              ...                     ...
# 995         995          996   Luciano Gyurko           IT Consultant
# 996         996          997    Morty Bradley   Cybersecurity Analyst
# 997         997          998    Eunice Tabert      IT Project Manager
# 998         998          999    Jojo Murrells            Data Analyst
# 999         999         1000     Todd Niblock  IT Security Specialist
#
#     Work_location             Mobile  salary                           Email  \
# ...

# %%
df.head(5)
# Out:
#    employee_id    Employee_name  Age Work_location            Mobile  salary  \
# 0            1  Joachim Coulman   35       Kolkata  +62 117 137 5068   70090
# 1            2    Fidela Fetter   29         Kochi  +62 214 683 4825  108385
# 2            3     Myles Laffan   32     Bangalore  +62 128 494 8668   18808
# 3            4   Myrtie Rraundl   34        Bhopal   +7 238 363 9693   88836
# 4            5       Janie Burd   26       Lucknow  +86 107 936 4328  103278
#
#                       Email Joining_date                   Role  Active  \
# 0       cgawith0@oracle.com   29/12/2021  Network Administrator  Active
# 1     ecansfield1@europa.eu   07/05/2022    IT Business Analyst   Leave
# 2  lravenshear2@samsung.com   23/03/2020        Cloud Architect   Leave
# 3          swickmann3@de.vu   03/04/2024  Network Administrator  Active
# 4     cmccambrois4@webs.com   20/11/2021  Cybersecurity Analyst   Leave
#
#           Manager_Name
# 0           Cad Gawith
# ...

# %%
df.isna().sum()
# Out:
# employee_id      0
# Employee_name    0
# Age              0
# Work_location    0
# Mobile           0
# salary           0
# Email            0
# Joining_date     0
# Role             0
# Active           0
# Manager_Name     0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# employee_id       int64
# Employee_name    object
# Age              object
# Work_location    object
# Mobile           object
# salary            int64
# Email            object
# Joining_date     object
# Role             object
# Active           object
# Manager_Name     object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
New = df.nlargest(3, 'salary', keep='first')
New
# Out:
#      Unnamed: 0  employee_id   Employee_name              Age Work_location  \
# 66           66           67  Sharon Chiplen    Web Developer     Ahmedabad
# 941         941          942     Hunter Abdy    Web Developer         Surat
# 230         230          231  Culver Mozzini  DevOps Engineer     Hyderabad
#
#                 Mobile  salary                    Email Joining_date  \
# 66    +62 193 180 1646  119944       npaulson1u@psu.edu   16/05/2024
# 941   +55 735 550 0882  119861  mmoxhamq5@indiegogo.com   15/05/2024
# 230  +242 658 408 6262  119820         rheyns6e@mapy.cz   20/02/2023
#
#                 Role Active      Manager_Name
# 66     Web Developer  Leave  Nickolai Paulson
# 941    Web Developer  Leave   Milicent Moxham
# 230  DevOps Engineer  Leave     Roselia Heyns

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'employee_id', 'Employee_name', 'Age', 'Work_location',
#        'Mobile', 'salary', 'Email', 'Joining_date', 'Role', 'Active',
#        'Manager_Name'],
#       dtype='object')

# %%
df.tail(8)
# Out:
#      employee_id     Employee_name  Age Work_location             Mobile  \
# 992          993  Brose Ryhorovich   35         Surat   +48 498 977 5478
# 993          994    Peyter Fossick   30     Ahmedabad  +505 860 442 8797
# 994          995   Stanton Bispham   23       Lucknow   +81 668 227 2308
# 995          996    Luciano Gyurko   30     Hyderabad  +234 524 682 2118
# 996          997     Morty Bradley   32         Delhi   +63 648 929 5978
# 997          998     Eunice Tabert   25       Kolkata   +86 360 546 8167
# 998          999     Jojo Murrells   25        Bhopal   +63 919 543 6908
# 999         1000      Todd Niblock   34         Kochi   +48 359 991 8481
#
#      salary                           Email Joining_date  \
# 992   53308                hbaserrk@who.int   10/10/2020
# 993   78893        vtewkesberryrl@cam.ac.uk   18/07/2020
# 994   12691                dbertrm@ucsd.edu   25/11/2022
# 995   49784             asymcockrn@webs.com   02/08/2020
# ...

# %%
df.count()
# Out:
# Unnamed: 0       1000
# employee_id      1000
# Employee_name    1000
# Age              1000
# Work_location    1000
# Mobile           1000
# salary           1000
# Email            1000
# Joining_date     1000
# Role             1000
# Active           1000
# Manager_Name     1000
# dtype: int64

# %%
df[df.Role =='Data Analyst']['Employee_name'].sum()
# Out:
# 'Clarke RookebyLoretta ChapierMuire AveyardBambie GirodiasBing SheeringAdelaide CasterotLouise ShillJacquelyn BeatonSelig ClewarthChristin GirardoniEngracia MadgeAlessandra PartrickCharil CoupmanAilis PearsGretel NightingaleDamara ScreenBertrand EmlochAundrea HebborneEdie SeamerCaria GallafantAdriana GillicuddyDarsey BamblettCarlene KalinskyArty CellierKerstin McGouganMerrily BottingGriffith CurrorVale ByrdeKlement DowseyShandra ThomingaKirstin ChidlerJammal FaasRichmond MeinsPatton HeinemannAllen LooksOdell BehneckeTanhya BaldazziCymbre KersawGaspard GirardeyKarl DressellMarta ThurnhamMicky SciussciettoJamima IckoviciHy UgolottiAbigale PembleBunny AntonikRebeca HarfootEldin RopkingFrazer KeeleEvelyn TunnToby PeperellMelosa CovetCharla BrogginiCurrey WhatesNichol ScarrottBarbey AberdeenDicky PetrovicMariele TolcharKellsie MorphewKingsly KrysztowczykBiron TinmouthDoretta FahrenbacherJoni DormerRubin BjorkanCandra GrimoldbyMelosa LambirdStanton BisphamJojo Murrells'

# %%
df.columns
# Out:
# Index(['employee_id', 'Employee_name', 'Age', 'Work_location', 'Mobile',
#        'salary', 'Email', 'Joining_date', 'Role', 'Active', 'Manager_Name'],
#       dtype='object')

# %%
df1=df.drop(['Age','Mobile','salary'],axis=1)

# %%
df.groupby('Work_location').sum().head(100)
# Out:
#                employee_id                                      Employee_name  \
# Work_location
# Ahmedabad            39485  Robbyn HelianSharon ChiplenBeverie LunoHonoria...
# Bangalore            33292  Myles LaffanRubia CharlestonRafe RoskillyIngab...
# Bhopal               34514  Myrtie RraundlMelisa WharramFrederique SherryL...
# Chennai              28710  Aldus RobbingsGiraud IbarraLoretta ChapierJesu...
# Delhi                35516  Pyotr PresnellFanechka PackhamSpence LeyAmargo...
# Hyderabad            36626  Fergus OleyCordy SmeetonJoan SimonelliBette-an...
# Indore               33126  Kattie McCurdyDerick ChasonCarey AntonognoliKe...
# Jaipur               32570  Vivyan GravenorFord RosenauTatiana VileUrsula ...
# Kochi                28528  Fidela FetterEvy BattyllMuire AveyardLilyan Be...
# Kolkata              34076  Joachim CoulmanAymer CullumFreddi SarraMarijn ...
# Lucknow              32939  Janie BurdVinny GidneyBarrie StandbridgeYetta ...
# ...

# %%
df['Age'].describe()
# Out:
# count                   1000
# unique                    15
# top       IT Project Manager
# freq                      77
# Name: Age, dtype: object

# %%
df['salary'].hist()
# Out:
# <Axes: >

# %%
df1=df[(df.Age >33)]
df1
# Out:
#      employee_id       Employee_name  Age Work_location             Mobile  \
# 0              1     Joachim Coulman   35       Kolkata   +62 117 137 5068
# 3              4      Myrtie Rraundl   34        Bhopal    +7 238 363 9693
# 8              9      Melisa Wharram   34        Bhopal   +55 126 458 9904
# 17            18       Sibbie Erratt   34          Pune   +86 178 240 3967
# 18            19      Trisha Farmloe   35        Nagpur   +33 583 665 4277
# ..           ...                 ...  ...           ...                ...
# 955          956       Judie Venmore   34         Surat   +93 407 780 4543
# 969          970  Brendon Greenhaugh   35        Bhopal    +1 463 600 3919
# 971          972   Hamnet Greenfield   34     Hyderabad  +220 705 942 8939
# 992          993    Brose Ryhorovich   35         Surat   +48 498 977 5478
# 999         1000        Todd Niblock   34         Kochi   +48 359 991 8481
#
# ...

# %%
df2=df['Joining_date'] = pd.to_datetime(df['Joining_date'])
df2
# Out:
# 0     2021-12-29
# 1     2022-05-07
# 2     2020-03-23
# 3     2024-04-03
# 4     2021-11-20
#          ...
# 995   2020-08-02
# 996   2023-09-28
# 997   2023-08-09
# 998   2022-07-14
# 999   2021-03-08
# Name: Joining_date, Length: 1000, dtype: datetime64[ns]

# %%
df2=df.drop(["salary", "Age"], axis = 1, inplace = True)

# %%
df1
# Out:
#      employee_id    Employee_name Work_location  \
# 0              1  Joachim Coulman       Kolkata
# 1              2    Fidela Fetter         Kochi
# 2              3     Myles Laffan     Bangalore
# 3              4   Myrtie Rraundl        Bhopal
# 4              5       Janie Burd       Lucknow
# ..           ...              ...           ...
# 995          996   Luciano Gyurko     Hyderabad
# 996          997    Morty Bradley         Delhi
# 997          998    Eunice Tabert       Kolkata
# 998          999    Jojo Murrells        Bhopal
# 999         1000     Todd Niblock         Kochi
#
#                               Email Joining_date                    Role  \
# 0               cgawith0@oracle.com   29/12/2021   Network Administrator
# 1             ecansfield1@europa.eu   07/05/2022     IT Business Analyst
# 2          lravenshear2@samsung.com   23/03/2020         Cloud Architect
# 3                  swickmann3@de.vu   03/04/2024   Network Administrator
# ...

# %%
df
# Out:
#      employee_id    Employee_name Work_location             Mobile  \
# 0              1  Joachim Coulman       Kolkata   +62 117 137 5068
# 1              2    Fidela Fetter         Kochi   +62 214 683 4825
# 2              3     Myles Laffan     Bangalore   +62 128 494 8668
# 3              4   Myrtie Rraundl        Bhopal    +7 238 363 9693
# 4              5       Janie Burd       Lucknow   +86 107 936 4328
# ..           ...              ...           ...                ...
# 995          996   Luciano Gyurko     Hyderabad  +234 524 682 2118
# 996          997    Morty Bradley         Delhi   +63 648 929 5978
# 997          998    Eunice Tabert       Kolkata   +86 360 546 8167
# 998          999    Jojo Murrells        Bhopal   +63 919 543 6908
# 999         1000     Todd Niblock         Kochi   +48 359 991 8481
#
#                               Email Joining_date                    Role  \
# 0               cgawith0@oracle.com   29/12/2021   Network Administrator
# ...

# %%
df[df.Work_location =='Chennai'].head(50)
# Out:
#      employee_id         Employee_name  Age Work_location             Mobile  \
# 11            12        Aldus Robbings   24       Chennai    +1 525 432 3937
# 41            42         Giraud Ibarra   26       Chennai   +86 186 826 8333
# 48            49       Loretta Chapier   30       Chennai    +7 663 619 8698
# 113          114         Jesus Janczyk   25       Chennai   +62 202 640 0364
# 116          117          Junie Bewley   30       Chennai  +507 843 650 6787
# 149          150      Joachim Willowby   23       Chennai  +221 495 991 2615
# 191          192     Emmye Shepherdson   22       Chennai   +86 628 735 7563
# 193          194        Joachim Rosita   29       Chennai   +62 531 355 8471
# 201          202         Dex Broadbury   28       Chennai   +33 636 765 2252
# 216          217       Sylvan Brunesco   23       Chennai   +33 132 138 2535
# 240          241           Gerda Gynne   22       Chennai   +51 162 314 4916
# ...

# %%
df.sort_values(by= ['Role'], ascending=True).head(100)
# Out:
#      employee_id      Employee_name  Age Work_location             Mobile  \
# 98            99      Nerta Studart   29        Jaipur    +1 937 313 7755
# 529          530     Christalle Wye   22         Delhi    +1 757 711 1682
# 206          207      Amabel D'Elia   29         Kochi    +7 682 619 5463
# 454          455     Price Brownsey   24     Bangalore   +86 770 733 4795
# 842          843    Karita Stealfox   24        Mumbai   +55 518 240 6189
# ..           ...                ...  ...           ...                ...
# 697          698       Salmon Raatz   32       Kolkata   +46 107 849 8977
# 271          272     Aurel Shepeard   31        Jaipur   +57 469 697 1488
# 740          741  Stevana Percifull   28        Jaipur   +63 939 873 6992
# 894          895    Alfonse Garrold   30         Kochi  +232 368 336 8441
# 492          493   Edsel Mulkerrins   26     Ahmedabad   +62 305 903 0936
#
#      salary                           Email Joining_date  \
# ...

# %%
df.duplicated('Age').head(100)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Length: 100, dtype: bool

# %%
df['Age'].interpolate()
# Out:
# 0      35
# 1      29
# 2      32
# 3      34
# 4      26
#        ..
# 995    30
# 996    32
# 997    25
# 998    25
# 999    34
# Name: Age, Length: 1000, dtype: int64

# %%
df['Age'].unique()
# Out:
# array([35, 29, 32, 34, 26, 27, 24, 23, 30, 31, 25, 28, 22, 33])

# %%
df1=df['Age']=df['Role'].astype('category')
df1
# Out:
# 0       Network Administrator
# 1         IT Business Analyst
# 2             Cloud Architect
# 3       Network Administrator
# 4       Cybersecurity Analyst
#                 ...
# 995             IT Consultant
# 996     Cybersecurity Analyst
# 997        IT Project Manager
# 998              Data Analyst
# 999    IT Security Specialist
# Name: Role, Length: 1000, dtype: category
# Categories (15, object): ['Cloud Architect', 'Cybersecurity Analyst', 'Data Analyst', 'Database Administrator', ..., 'Software Developer', 'Systems Engineer', 'UX/UI Designer', 'Web Developer']

# %%
df['Age'].nunique()
# Out:
# 14

# %%
df.to_excel(r'C:\Users\Ponnambalam\OneDrive\Desktop\Employees__data.xlsx')

# %%
df.shape
# Out:
# (1000, 11)

# %%
df1=df.duplicated().any()
df1
# Out:
# np.False_

# %%
df.loc[df['Role'].isna(), 'Role'] = 0
df
# Out:
#      employee_id    Employee_name                     Age Work_location  \
# 0              1  Joachim Coulman   Network Administrator       Kolkata
# 1              2    Fidela Fetter     IT Business Analyst         Kochi
# 2              3     Myles Laffan         Cloud Architect     Bangalore
# 3              4   Myrtie Rraundl   Network Administrator        Bhopal
# 4              5       Janie Burd   Cybersecurity Analyst       Lucknow
# ..           ...              ...                     ...           ...
# 995          996   Luciano Gyurko           IT Consultant     Hyderabad
# 996          997    Morty Bradley   Cybersecurity Analyst         Delhi
# 997          998    Eunice Tabert      IT Project Manager       Kolkata
# 998          999    Jojo Murrells            Data Analyst        Bhopal
# 999         1000     Todd Niblock  IT Security Specialist         Kochi
#
#      salary                           Email Joining_date  \
# ...

# %%
df.sort_values(by='Age'
# Out:
#      employee_id    Employee_name              Age Work_location  \
# 98            99    Nerta Studart  Cloud Architect        Jaipur
# 529          530   Christalle Wye  Cloud Architect         Delhi
# 206          207    Amabel D'Elia  Cloud Architect         Kochi
# 454          455   Price Brownsey  Cloud Architect     Bangalore
# 842          843  Karita Stealfox  Cloud Architect        Mumbai
# ..           ...              ...              ...           ...
# 152          153  Augusto Fontell    Web Developer     Hyderabad
# 883          884    Arluene Viger    Web Developer       Kolkata
# 443          444  Grissel Hellier    Web Developer     Bangalore
# 367          368   Dorree Minmagh    Web Developer       Chennai
# 413          414     Bayard Youde    Web Developer        Nagpur
#
#                 Mobile  salary                           Email Joining_date  \
# 98     +1 937 313 7755   95362          rmcmonnies2q@adobe.com   03/05/2024
# ...

# %%
df.sample(frac=0.30,random_state=100)
# Out:
#      employee_id     Employee_name                     Age Work_location  \
# 249          250  Jephthah Ranking          UX/UI Designer        Mumbai
# 353          354    Feliks Attwell   Cybersecurity Analyst        Jaipur
# 537          538       Burty Talks  IT Security Specialist       Chennai
# 424          425     Cherri Newlan           Web Developer       Kolkata
# 564          565  Gaspard Girardey            Data Analyst          Pune
# ..           ...               ...                     ...           ...
# 193          194    Joachim Rosita      Software Developer       Chennai
# 838          839    Wenda Spencers     IT Business Analyst         Delhi
# 974          975      Nadia Moneti         DevOps Engineer        Bhopal
# 203          204   Fleming Roelofs   Cybersecurity Analyst        Nagpur
# 425          426     Peterus Rosel      IT Project Manager     Ahmedabad
#
#                 Mobile  salary                         Email Joining_date  \
# ...

# %%
df['Role'].hist()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['employee_id', 'Employee_name', 'Age', 'Work_location', 'Mobile',
#        'salary', 'Email', 'Joining_date', 'Role', 'Active', 'Manager_Name'],
#       dtype='object')

# %%
df3 = df[df['Role'] == 'IT Security Specialist']

# %%
df3
# Out:
#      employee_id         Employee_name                     Age  \
# 12            13      Heidi Ivashnikov  IT Security Specialist
# 35            36         Amargo Lamden  IT Security Specialist
# 41            42         Giraud Ibarra  IT Security Specialist
# 53            54        Brinn Mariolle  IT Security Specialist
# 64            65        Flss O' Dooley  IT Security Specialist
# 84            85         Abelard Suter  IT Security Specialist
# 111          112        Judith Gounard  IT Security Specialist
# 126          127        Crissy Kingzet  IT Security Specialist
# 155          156     Winthrop Seacombe  IT Security Specialist
# 166          167       Fayette Leisman  IT Security Specialist
# 168          169       Thom Wardingley  IT Security Specialist
# 186          187          Paolina Cage  IT Security Specialist
# 188          189       Dulcea Mountlow  IT Security Specialist
# 196          197           Arda Kornas  IT Security Specialist
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# employee_id      0
# Employee_name    0
# Age              0
# Work_location    0
# Mobile           0
# salary           0
# Email            0
# Joining_date     0
# Role             0
# Active           0
# Manager_Name     0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# employee_id       int64
# Employee_name    object
# Age              object
# Work_location    object
# Mobile           object
# salary            int64
# Email            object
# Joining_date     object
# Role             object
# Active           object
# Manager_Name     object
# dtype: object

# %%
df.shape
# Out:
# (1000, 12)

# %%
df['Age'].median()
# Out:
# np.float64(28.0)

# %%
 df3=df['Role'] == 'Network Administrator'
 df4=df['Role'] == 'IT Business Analyst'

# %%
df.query('Role != "Web Developer" ').head(10)
# Out:
#    employee_id    Employee_name                     Age Work_location  \
# 0            1  Joachim Coulman   Network Administrator       Kolkata
# 1            2    Fidela Fetter     IT Business Analyst         Kochi
# 2            3     Myles Laffan         Cloud Architect     Bangalore
# 3            4   Myrtie Rraundl   Network Administrator        Bhopal
# 4            5       Janie Burd   Cybersecurity Analyst       Lucknow
# 5            6  Vivyan Gravenor         DevOps Engineer        Jaipur
# 6            7   Cammy Slafford        Systems Engineer        Nagpur
# 7            8     Natasha Alpe  Database Administrator          Pune
# 8            9   Melisa Wharram         DevOps Engineer        Bhopal
# 9           10        Lane Meir      IT Project Manager        Mumbai
#
#              Mobile  salary                        Email Joining_date  \
# 0  +62 117 137 5068   70090          cgawith0@oracle.com   29/12/2021
# ...

# %%
df1=df.sort_values(by='Role',ascending=False).head(10)
df1
# Out:
#      employee_id      Employee_name            Age Work_location  \
# 500          501   Merwin Hatcliffe  Web Developer        Nagpur
# 247          248    Mei Antognozzii  Web Developer          Pune
# 853          854    Buckie Dombrell  Web Developer     Hyderabad
# 510          511  Jefferey Sinncock  Web Developer         Surat
# 514          515       Cally Sparke  Web Developer         Surat
# 424          425      Cherri Newlan  Web Developer       Kolkata
# 521          522     Jarvis Breeton  Web Developer     Ahmedabad
# 417          418       Brooks Fleis  Web Developer       Lucknow
# 117          118     Ryley Escudier  Web Developer        Jaipur
# 761          762   Keefer Shannahan  Web Developer       Chennai
#
#                 Mobile  salary                      Email Joining_date  \
# 500   +86 191 941 3278   77773        agiovanidw@phoca.cz   18/04/2024
# 247   +93 404 700 1588  115231           sdunn6v@ucla.edu   19/02/2023
# ...

# %%
df['salary'].value_counts()
# Out:
# salary
# 44143     2
# 81520     2
# 115053    2
# 8250      2
# 103720    2
#          ..
# 49784     1
# 25183     1
# 25325     1
# 37610     1
# 50197     1
# Name: count, Length: 994, dtype: int64

# %%
df['salary'].unique()
# Out:
# array([ 18423.17,  69321.22, 123783.46,  72759.73,  21976.67, 128599.5 ,
#         45594.34, 103158.  , 115043.74,  89291.14,  32139.06,  93971.01,
#         23085.32,  67734.69,  88010.84,  34544.98, 112721.79,  52675.04,
#         99536.73,  19619.95,  82778.59,  30805.01,  96509.45,  66704.22,
#         78206.97, 102399.05,  15458.14, 116385.98,  60421.02,  64370.69,
#         63481.81,  64937.21,  36565.73,  99721.49,  72975.2 ,  81717.82,
#         62870.86,  42871.74,  64654.01,  53407.21,  88766.32, 121156.37,
#         15290.51,  47697.57, 119717.6 ,  98556.36,  67801.67,  93370.37,
#         15463.93,  66073.53, 100369.  ,  52015.88,  69993.75,  81657.7 ,
#         37977.86,  68414.86,  23965.37, 108363.38,  23379.54,  83304.07,
#         40922.87,  86134.9 ,  93508.55,  22942.54,  43139.37, 128514.41,
#        100886.87,  63444.59,  66136.67,  89141.54,  87624.51,  31885.16,
#        104319.76, 108076.2 ,  31575.26, 117847.9 ,  37670.43,  81095.14,
# ...

# %%
df.groupby('salary') ['Age'].mean()
# Out:
# salary
# 2107      33.0
# 2130      29.0
# 2538      23.0
# 2699      24.0
# 2756      35.0
#           ...
# 119363    34.0
# 119371    27.0
# 119820    28.0
# 119861    24.0
# 119944    27.0
# Name: Age, Length: 994, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   employee_id    1000 non-null   int64
#  1   Employee_name  1000 non-null   object
#  2   Age            1000 non-null   int64
#  3   Work_location  1000 non-null   object
#  4   Mobile         1000 non-null   object
#  5   salary         1000 non-null   int64
#  6   Email          1000 non-null   object
#  7   Joining_date   1000 non-null   object
#  8   Role           1000 non-null   object
#  9   Active         1000 non-null   object
#  10  Manager_Name   1000 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 86.1+ KB

# %%
df.count()
# Out:
# employee_id      1000
# Employee_name    1000
# Age              1000
# Work_location    1000
# Mobile           1000
# salary           1000
# Email            1000
# Joining_date     1000
# Role             1000
# Active           1000
# Manager_Name     1000
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df.sum()
# Out:
# employee_id                                                 500500
# Employee_name    Joachim CoulmanFidela FetterMyles LaffanMyrtie...
# Age                                                          28322
# Work_location    KolkataKochiBangaloreBhopalLucknowJaipurNagpur...
# Mobile           +62 117 137 5068+62 214 683 4825+62 128 494 86...
# salary                                                    60117236
# Email            cgawith0@oracle.comecansfield1@europa.eulraven...
# Joining_date     29/12/202107/05/202223/03/202003/04/202420/11/...
# Role             Network AdministratorIT Business AnalystCloud ...
# Active           ActiveLeaveLeaveActiveLeaveLeaveLeaveActiveAct...
# Manager_Name     Cad GawithElvina CansfieldLyon RavenshearSiann...
# dtype: object

# %%
df.mode()
# Out:
#      employee_id      Employee_name   Age Work_location             Mobile  \
# 0              1           Ab Major  23.0        Mumbai    +1 100 930 3325
# 1              2       Abbey Defont   NaN           NaN    +1 202 848 7439
# 2              3         Abbi Friel   NaN           NaN    +1 205 194 6586
# 3              4       Abby Lawleff   NaN           NaN    +1 212 694 8720
# 4              5      Abelard Suter   NaN           NaN    +1 214 192 1300
# ..           ...                ...   ...           ...                ...
# 995          996   Zaccaria Bethune   NaN           NaN  +994 661 771 1934
# 996          997   Zacharie Waldram   NaN           NaN  +994 852 906 4539
# 997          998  Zaneta Ryhorovich   NaN           NaN  +998 338 588 5046
# 998          999         Zenia Lind   NaN           NaN  +998 380 111 7787
# 999         1000        Zerk Aggott   NaN           NaN  +998 812 808 2703
#
# ...

# %%
df.std
# Out:
# <bound method DataFrame.std of      employee_id    Employee_name  Age Work_location             Mobile  \
# 0              1  Joachim Coulman   35       Kolkata   +62 117 137 5068
# 1              2    Fidela Fetter   29         Kochi   +62 214 683 4825
# 2              3     Myles Laffan   32     Bangalore   +62 128 494 8668
# 3              4   Myrtie Rraundl   34        Bhopal    +7 238 363 9693
# 4              5       Janie Burd   26       Lucknow   +86 107 936 4328
# ..           ...              ...  ...           ...                ...
# 995          996   Luciano Gyurko   30     Hyderabad  +234 524 682 2118
# 996          997    Morty Bradley   32         Delhi   +63 648 929 5978
# 997          998    Eunice Tabert   25       Kolkata   +86 360 546 8167
# 998          999    Jojo Murrells   25        Bhopal   +63 919 543 6908
# 999         1000     Todd Niblock   34         Kochi   +48 359 991 8481
#
#      salary                           Email Joining_date  \
# ...

# %%
df5=df.duplicated()

# %%
df5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.columns
# Out:
# Index(['employee_id', 'Employee_name', 'Age', 'Work_location', 'Mobile',
#        'salary', 'Email', 'Joining_date', 'Role', 'Active', 'Manager_Name'],
#       dtype='object')

# %%
df['Role'].value_counts().head()
# Out:
# Role
# IT Project Manager       77
# Cybersecurity Analyst    73
# Cloud Architect          72
# DevOps Engineer          70
# Software Developer       69
# Name: count, dtype: int64

# %%
df['Role']
# Out:
# 0       Network Administrator
# 1         IT Business Analyst
# 2             Cloud Architect
# 3       Network Administrator
# 4       Cybersecurity Analyst
#                 ...
# 995             IT Consultant
# 996     Cybersecurity Analyst
# 997        IT Project Manager
# 998              Data Analyst
# 999    IT Security Specialist
# Name: Role, Length: 1000, dtype: object

# %%
df['Age'].nunique()
# Out:
# 14

# %%
len(df[df['Role'].str.contains('Data Analyst')])
# Out:
# 68

# %%
df[df['Role']==' Cybersecurity Analyst']['Employee_name']
# Out:
# Series([], Name: Employee_name, dtype: object)

# %%
df.columns
# Out:
# Index(['employee id', 'employee name', 'age', 'work location', 'gender',
#        'salary', 'mobile', 'designation', 'joining date', 'experience',
#        'shift timing', 'department', 'manager name'],
#       dtype='object')

# %%
df['Role'].value_counts()
# Out:
# Role
# IT Project Manager        77
# Cybersecurity Analyst     73
# Cloud Architect           72
# DevOps Engineer           70
# Software Developer        69
# Data Analyst              68
# UX/UI Designer            68
# Web Developer             65
# Database Administrator    65
# IT Business Analyst       65
# Systems Engineer          65
# Network Administrator     64
# IT Consultant             62
# IT Support Specialist     61
# IT Security Specialist    56
# Name: count, dtype: int64

# %%
dfnew=df.fillna('HR')

# %%
dfnew
# Out:
#      employee_id    Employee_name  Age Work_location             Mobile  \
# 0              1  Joachim Coulman   35       Kolkata   +62 117 137 5068
# 1              2    Fidela Fetter   29         Kochi   +62 214 683 4825
# 2              3     Myles Laffan   32     Bangalore   +62 128 494 8668
# 3              4   Myrtie Rraundl   34        Bhopal    +7 238 363 9693
# 4              5       Janie Burd   26       Lucknow   +86 107 936 4328
# ..           ...              ...  ...           ...                ...
# 995          996   Luciano Gyurko   30     Hyderabad  +234 524 682 2118
# 996          997    Morty Bradley   32         Delhi   +63 648 929 5978
# 997          998    Eunice Tabert   25       Kolkata   +86 360 546 8167
# 998          999    Jojo Murrells   25        Bhopal   +63 919 543 6908
# 999         1000     Todd Niblock   34         Kochi   +48 359 991 8481
#
#      salary                           Email Joining_date  \
# ...

# %%
df[df['Role'].isin(['Data Analyst', 'Cybersecurity Analyst'])]
# Out:
#      Unnamed: 0  employee_id      Employee_name                    Age  \
# 4             4            5         Janie Burd  Cybersecurity Analyst
# 14           14           15        Fergus Oley  Cybersecurity Analyst
# 16           16           17     Kattie McCurdy  Cybersecurity Analyst
# 17           17           18      Sibbie Erratt  Cybersecurity Analyst
# 20           20           21  Lisabeth Sisselot  Cybersecurity Analyst
# ..          ...          ...                ...                    ...
# 982         982          983       Waiter Couch  Cybersecurity Analyst
# 990         990          991   Boniface Creavin  Cybersecurity Analyst
# 994         994          995    Stanton Bispham           Data Analyst
# 996         996          997      Morty Bradley  Cybersecurity Analyst
# 998         998          999      Jojo Murrells           Data Analyst
#
#     Work_location             Mobile  salary                      Email  \
# ...

# %%
df[df['salary']>55000].head(100)
# Out:
#      employee_id    Employee_name  Age Work_location             Mobile  \
# 0              1  Joachim Coulman   35       Kolkata   +62 117 137 5068
# 1              2    Fidela Fetter   29         Kochi   +62 214 683 4825
# 3              4   Myrtie Rraundl   34        Bhopal    +7 238 363 9693
# 4              5       Janie Burd   26       Lucknow   +86 107 936 4328
# 7              8     Natasha Alpe   26          Pune   +86 915 633 2245
# ..           ...              ...  ...           ...                ...
# 196          197      Arda Kornas   28     Ahmedabad  +972 143 159 8124
# 197          198     Edan Morling   22         Kochi   +48 836 916 6966
# 201          202    Dex Broadbury   28       Chennai   +33 636 765 2252
# 202          203      Angy Sewley   33          Pune   +62 926 701 2568
# 203          204  Fleming Roelofs   26        Nagpur   +52 302 214 5513
#
#      salary                           Email Joining_date  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot()
plt.show()

# %%
plt.bar(df['salary'],df['Age'])
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.hist(df['Work_location'],bins=5,color='b',
         edgecolor='black')
# Out:
# (array([194., 196., 206., 194., 210.]),
#  array([ 0. ,  2.8,  5.6,  8.4, 11.2, 14. ]),
#  <BarContainer object of 5 artists>)
